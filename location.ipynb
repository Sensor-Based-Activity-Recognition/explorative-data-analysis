# %% [markdown]
# # Setup

# %%
import io
import requests
import pandas as pd
from urllib.parse import quote

# %%
def get_data_from_query(query):
    # convert query to url compatible string
    query = quote(query)
    # get data via get request
    r = requests.get(f"http://docker.caracal-lime.ts.net:9000/exp?query={query}")
    # parse data into pandas dataframe
    data = pd.read_csv(io.StringIO(r.text))
    # check if timestamp is in dataframe
    if "timestamp" in data.columns:
        # if so, convert to datetime and set as index
        data["timestamp"] = pd.to_datetime(data["timestamp"])
        data.set_index("timestamp", inplace=True)
    # return
    return data

# %% [markdown]
# # Analyse

# %%
data = get_data_from_query(
    """
    SELECT 
        LocationGps_x, 
        LocationGps_y, 
        LocationGps_z, 
        LocationGps_latitude, 
        LocationGps_longitude 
    FROM 
        prod;
    """
)

data.sample(10)
# Out:
#          LocationGps_x  LocationGps_y  LocationGps_z  LocationGps_latitude  \
# 1458043            NaN            NaN            NaN                   NaN
# 2388886            NaN            NaN            NaN                   NaN
# 3869043            NaN            NaN            NaN                   NaN
# 1876812            NaN            NaN            NaN                   NaN
# 3781291            NaN            NaN            NaN                   NaN
# 3040968            NaN            NaN            NaN                   NaN
# 488588             NaN            NaN            NaN                   NaN
# 4104738            NaN            NaN            NaN                   NaN
# 3517156            NaN            NaN            NaN                   NaN
# 3351273            NaN            NaN            NaN                   NaN
#
#          LocationGps_longitude
# 1458043                    NaN
# 2388886                    NaN
# 3869043                    NaN
# 1876812                    NaN
# 3781291                    NaN
# 3040968                    NaN
# 488588                     NaN
# 4104738                    NaN
# 3517156                    NaN
# 3351273                    NaN

# %%
data.describe()
# Out:
#        LocationGps_x  LocationGps_y  LocationGps_z  LocationGps_latitude  \
# count            0.0            0.0            0.0           2018.000000
# mean             NaN            NaN            NaN             47.443767
# std              NaN            NaN            NaN              0.000927
# min              NaN            NaN            NaN             47.442741
# 25%              NaN            NaN            NaN             47.443233
# 50%              NaN            NaN            NaN             47.443378
# 75%              NaN            NaN            NaN             47.444069
# max              NaN            NaN            NaN             47.446896
#
#        LocationGps_longitude
# count            2018.000000
# mean                7.909713
# std                 0.003083
# min                 7.906073
# 25%                 7.907109
# 50%                 7.908565
# 75%                 7.912853
# max                 7.916430

# %% [markdown]
# Hier erkennen wir, dass die Spalten LocationGps_x, _y, _z nur NA Werte enthalten. Diese Spalten werden daher nicht verwendet.
# Jedoch gibt es einige Werte in den Spalten LocationGps_latitude und _longitude. Diese schauen wir genauer an.

# %%
data = get_data_from_query(
    """
    SELECT 
        timestamp, 
        LocationGps_latitude, 
        LocationGps_longitude, 
        activity, 
        hash, 
        person 
    FROM 
        prod 
    WHERE 
        LocationGps_latitude != NULL;
    """
)

data.sample(10)
# Out:
#                                   LocationGps_latitude  LocationGps_longitude  \
# timestamp
# 2023-03-16 19:17:15.930000+00:00             47.443321               7.907547
# 2023-03-16 19:19:34.920000+00:00             47.443321               7.908099
# 2023-03-08 16:59:29.740000+00:00             47.442772               7.906107
# 2023-03-12 13:16:14.030000+00:00             47.444942               7.914578
# 2023-03-16 19:16:46.900000+00:00             47.443378               7.907991
# 2023-03-12 13:20:35.030000+00:00             47.446629               7.913764
# 2023-03-12 13:09:15.030000+00:00             47.443329               7.908169
# 2023-03-12 13:23:43.030000+00:00             47.445461               7.914452
# 2023-03-16 19:20:15.930000+00:00             47.443302               7.907390
# 2023-03-08 16:54:09.710000+00:00             47.442890               7.906150
#
#                                     activity  \
# timestamp
# 2023-03-16 19:17:15.930000+00:00  Velofahren
# 2023-03-16 19:19:34.920000+00:00  Velofahren
